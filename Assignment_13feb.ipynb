# %%
1. Explain why we have to use the Exception class while creating a Custom Exception.

By doing this, we have the flexibility to define our own behavior and attributes for the exception.
Example:
we create a new class called CustomError which is derived from the base Exception class. 

class CustomError(Exception):
    ...
    pass

In the try block, we place the code that might raise the custom exception. If the exception occurs, it will be caught 
by the except block specifically designed to handle the CustomError. Here, we can include the necessary actions to be 
taken when the exception is encountered.

try:
    # Code that may raise the custom exception
    ...
    
except CustomError:
    # Handling the custom exception
    ...

# %%
2. Write a python program to print Python Exception Hierarchy.

# %%
def print_exception_hierarchy():
    exceptions = []
    for exception in dir(__builtins__):
        if isinstance(getattr(__builtins__, exception), type) and issubclass(getattr(__builtins__, exception), Exception):
            exceptions.append(exception)
            exceptions.sort() 
        for exception in exceptions: 
                print(exception)

# %%
print_exception_hierarchy()
# Out:
# ArithmeticError
# ArithmeticError
# AssertionError
# ArithmeticError
# AssertionError
# AttributeError
# ArithmeticError
# AssertionError
# AttributeError
# ArithmeticError
# AssertionError
# AttributeError
# BlockingIOError
# ArithmeticError
# AssertionError
# AttributeError
# BlockingIOError
# BrokenPipeError
# ArithmeticError
# AssertionError
# AttributeError
# BlockingIOError
# BrokenPipeError
# BufferError
# ArithmeticError
# AssertionError
# AttributeError
# BlockingIOError
# BrokenPipeError
# BufferError
# BytesWarning
# ArithmeticError
# AssertionError
# AttributeError
# BlockingIOError
# BrokenPipeError
# BufferError
# BytesWarning
# ChildProcessError
# ArithmeticError
# AssertionError
# AttributeError
# BlockingIOError
# BrokenPipeError
# BufferError
# BytesWarning
# ChildProcessError
# ConnectionAbortedError
# ArithmeticError
# AssertionError
# AttributeError
# BlockingIOError
# BrokenPipeError
# BufferError
# BytesWarning
# ChildProcessError
# ConnectionAbortedError
# ...

# %%
3.What errors are defined in the ArithmeticError class? Explain any two with an example.

ArithmeticError is simply an error that occurs during numeric calculations.

ArithmeticError types in Python include:

OverFlowError
ZeroDivisionError
FloatingPointError
These errors are all capable of crashing a code in Python. It is essential to catch an error because we do not want 
our code to crash as a result of incorrect input from a user.

# %%
# Example-1:

try:
    arithmetic = 5/0
except ZeroDivisionError as arithmetic:
    print(arithmetic)
# Out:
# division by zero

# %%
# Example-2:

j = 5.0
try:
    for i in range(1, 1000):
        j = j**i
except OverflowError as e:
      print(f"{e}, {e.__class__}")
# Out:
# (34, 'Numerical result out of range'), <class 'OverflowError'>

# %%
4. Why LookupError class is used? Explain with an example KeyError and IndexError.

The LookupError exception in Python forms the base class for all exceptions that are raised when an index or a key 
is not found for a sequence or dictionary respectively.

We can use LookupError exception class to handle both IndexError and KeyError exception classes.

# %%
# Example-IndexError:

a=[1,2,3,4]
try:
    a[6]
except IndexError as e:
    print(f"{e}, {e.__class__}")
# Out:
# list index out of range, <class 'IndexError'>

# %%
# Example-KeyError:

a={1:'shikha','id':12365,'mail':'sharma@gmail.com'}
try:
    print(a['name'])
except KeyError as e:
    print(f"{e}, {e.__class__}")
# Out:
# 'name'

# %%
5. Explain ImportError. What is ModuleNotFoundError?

Python’s ImportError (ModuleNotFoundError) indicates that you tried to import a module that Python doesn’t find.
An ImportError is detected when Python has problems with a successful module import. Usually this problem is caused by 
the incorrect path and is usually displayed with the message that there is “No module named (…)” or “cannot import name (…)”.

# %%
# Example:

try:
    import stem
except ImportError as e:
    print(f"{e}, {e.__class__}")
# Out:
# No module named 'stem', <class 'ModuleNotFoundError'>

# %%
6. List down some best practices for exception handling in python. 

a. Always use specific exception not a generic one in any circumstances. Instead of using special class Exception for
   handling exceptions, always use generic one like Zero division error.
b. Print always a proper message while handling exception.
c. Always try to log the error, so that errors produced can be look up and fixed.
d. Always avoid to write multiple exception handling.
e. Document All Exceptions Thrown by a Function.
f. Always cleanup all the resources in a Finally block.
